# %%
import time
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers import Activation
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras_sequential_ascii import sequential_model_to_ascii_printout
from keras import backend as K
if K.backend()=='tensorflow':
    K.common.set_image_dim_ordering("th")
 
# Import Tensorflow with multiprocessing
import tensorflow as tf
import multiprocessing as mp
 
# Loading the CIFAR-10 datasets
from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
# Declare variables
 
batch_size = 32 
# 32 examples in a mini-batch, smaller batch size means more updates in one epoch
 
num_classes = 10 #
epochs = 60 # repeat 20 times

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
print('Train: X=%s, y=%s' % (x_train.shape, y_train.shape))
print('Test: X=%s, y=%s' % (x_test.shape, y_test.shape))
# plot first few images
for i in range(9):
    # define subplot
    plt.subplot(330 + 1 + i)
    # plot raw pixel data
    plt.imshow(x_train[i])
# show the figure
plt.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 1)
# Test: X=(10000, 32, 32, 3), y=(10000, 1)

# %%
y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test, num_classes)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train  /= 255
x_test /= 255

# %%
def base_model():

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
#     model.add(MaxPooling2D(pool_size=(2,2)))
#     model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(1,1)))
    model.add(Dropout(0.2))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
#     model.add(MaxPooling2D())
#     model.add(Dropout(0.2))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
#     model.add(Conv2D(8, (3, 3), activation='relu'))
#     model.add(MaxPooling2D())
#     model.add(Dropout(0.2))
    model.add(Flatten())
#     model.add(Dense(512, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))

# Train model

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
cnn_n = base_model()
cnn_n.summary()

# Fit model

cnn = cnn_n.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test,y_test),shuffle=True)
# Out:
# Model: "sequential_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_78 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d_58 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_79 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_59 (MaxPooling (None, 7, 7, 32)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_80 (Conv2D)           (None, 7, 7, 64)          18496
# _________________________________________________________________
# conv2d_81 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_82 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# conv2d_83 (Conv2D)           (None, 3, 3, 128)         147584
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 128)               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_33 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                650
# =================================================================
# Total params: 312,426
# Trainable params: 312,426
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/60
# 50000/50000 [==============================] - 56s 1ms/step - loss: 1.7371 - accuracy: 0.3434 - val_loss: 1.4346 - val_accuracy: 0.4723
# Epoch 2/60
# 50000/50000 [==============================] - 59s 1ms/step - loss: 1.3540 - accuracy: 0.5091 - val_loss: 1.2150 - val_accuracy: 0.5595
# Epoch 3/60
# 50000/50000 [==============================] - 62s 1ms/step - loss: 1.1972 - accuracy: 0.5711 - val_loss: 1.0968 - val_accuracy: 0.6089
# Epoch 4/60
# 50000/50000 [==============================] - 60s 1ms/step - loss: 1.1031 - accuracy: 0.6090 - val_loss: 1.0127 - val_accuracy: 0.6450
# Epoch 5/60
# 50000/50000 [==============================] - 61s 1ms/step - loss: 1.0298 - accuracy: 0.6356 - val_loss: 0.9706 - val_accuracy: 0.6582
# Epoch 6/60
# 50000/50000 [==============================] - 60s 1ms/step - loss: 0.9772 - accuracy: 0.6554 - val_loss: 0.9574 - val_accuracy: 0.6671
# Epoch 7/60
# 50000/50000 [==============================] - 61s 1ms/step - loss: 0.9267 - accuracy: 0.6735 - val_loss: 0.8937 - val_accuracy: 0.6904
# Epoch 8/60
# 50000/50000 [==============================] - 61s 1ms/step - loss: 0.8870 - accuracy: 0.6894 - val_loss: 0.8545 - val_accuracy: 0.7025
# Epoch 9/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.8493 - accuracy: 0.7038 - val_loss: 0.8496 - val_accuracy: 0.7056
# Epoch 10/60
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.8253 - accuracy: 0.7123 - val_loss: 0.7951 - val_accuracy: 0.7232
# Epoch 11/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.8008 - accuracy: 0.7220 - val_loss: 0.8023 - val_accuracy: 0.7225
# Epoch 12/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.7813 - accuracy: 0.7296 - val_loss: 0.7869 - val_accuracy: 0.7303
# Epoch 13/60
# 50000/50000 [==============================] - 69s 1ms/step - loss: 0.7614 - accuracy: 0.7358 - val_loss: 0.7790 - val_accuracy: 0.7327
# Epoch 14/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.7409 - accuracy: 0.7427 - val_loss: 0.7772 - val_accuracy: 0.7395
# Epoch 15/60
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.7236 - accuracy: 0.7489 - val_loss: 0.7775 - val_accuracy: 0.7359
# Epoch 16/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.7107 - accuracy: 0.7523 - val_loss: 0.7269 - val_accuracy: 0.7534
# Epoch 17/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.7069 - accuracy: 0.7565 - val_loss: 0.7471 - val_accuracy: 0.7420
# Epoch 18/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.6904 - accuracy: 0.7599 - val_loss: 0.7762 - val_accuracy: 0.7401
# Epoch 19/60
# 50000/50000 [==============================] - 65s 1ms/step - loss: 0.6864 - accuracy: 0.7641 - val_loss: 0.7255 - val_accuracy: 0.7541
# Epoch 20/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.6694 - accuracy: 0.7683 - val_loss: 0.8015 - val_accuracy: 0.7327
# Epoch 21/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.6661 - accuracy: 0.7713 - val_loss: 0.7406 - val_accuracy: 0.7516
# Epoch 22/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.6536 - accuracy: 0.7729 - val_loss: 0.7197 - val_accuracy: 0.7570
# Epoch 23/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.6394 - accuracy: 0.7792 - val_loss: 0.7087 - val_accuracy: 0.7642
# Epoch 24/60
# 50000/50000 [==============================] - 70s 1ms/step - loss: 0.6365 - accuracy: 0.7815 - val_loss: 0.7206 - val_accuracy: 0.7624
# Epoch 25/60
# 50000/50000 [==============================] - 69s 1ms/step - loss: 0.6247 - accuracy: 0.7853 - val_loss: 0.7107 - val_accuracy: 0.7609
# Epoch 26/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.6221 - accuracy: 0.7843 - val_loss: 0.7315 - val_accuracy: 0.7565
# Epoch 27/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.6116 - accuracy: 0.7898 - val_loss: 0.7027 - val_accuracy: 0.7648
# Epoch 28/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.6035 - accuracy: 0.7910 - val_loss: 0.7232 - val_accuracy: 0.7593
# Epoch 29/60
# 50000/50000 [==============================] - 60s 1ms/step - loss: 0.6020 - accuracy: 0.7902 - val_loss: 0.7001 - val_accuracy: 0.7678
# Epoch 30/60
# 50000/50000 [==============================] - 58s 1ms/step - loss: 0.5921 - accuracy: 0.7945 - val_loss: 0.7172 - val_accuracy: 0.7627
# Epoch 31/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.5897 - accuracy: 0.7962 - val_loss: 0.7106 - val_accuracy: 0.7625
# Epoch 32/60
# 50000/50000 [==============================] - 63s 1ms/step - loss: 0.5877 - accuracy: 0.7984 - val_loss: 0.7270 - val_accuracy: 0.7626
# Epoch 33/60
# 50000/50000 [==============================] - 58s 1ms/step - loss: 0.5797 - accuracy: 0.8011 - val_loss: 0.7249 - val_accuracy: 0.7615
# Epoch 34/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5728 - accuracy: 0.8019 - val_loss: 0.7118 - val_accuracy: 0.7653
# Epoch 35/60
# 50000/50000 [==============================] - 64s 1ms/step - loss: 0.5583 - accuracy: 0.8085 - val_loss: 0.7261 - val_accuracy: 0.7653
# Epoch 36/60
# 50000/50000 [==============================] - 69s 1ms/step - loss: 0.5547 - accuracy: 0.8085 - val_loss: 0.7313 - val_accuracy: 0.7615
# Epoch 37/60
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.5577 - accuracy: 0.8073 - val_loss: 0.7088 - val_accuracy: 0.7683
# Epoch 38/60
# 50000/50000 [==============================] - 63s 1ms/step - loss: 0.5497 - accuracy: 0.8103 - val_loss: 0.7093 - val_accuracy: 0.7699
# Epoch 39/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5439 - accuracy: 0.8141 - val_loss: 0.7080 - val_accuracy: 0.7656
# Epoch 40/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5379 - accuracy: 0.8155 - val_loss: 0.7138 - val_accuracy: 0.7705
# Epoch 41/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5386 - accuracy: 0.8155 - val_loss: 0.7039 - val_accuracy: 0.7715
# Epoch 42/60
# 50000/50000 [==============================] - 62s 1ms/step - loss: 0.5326 - accuracy: 0.8161 - val_loss: 0.7184 - val_accuracy: 0.7678
# Epoch 43/60
# 50000/50000 [==============================] - 62s 1ms/step - loss: 0.5218 - accuracy: 0.8206 - val_loss: 0.7449 - val_accuracy: 0.7621
# Epoch 44/60
# 50000/50000 [==============================] - 63s 1ms/step - loss: 0.5174 - accuracy: 0.8224 - val_loss: 0.6928 - val_accuracy: 0.7817
# Epoch 45/60
# 50000/50000 [==============================] - 66s 1ms/step - loss: 0.5218 - accuracy: 0.8218 - val_loss: 0.6871 - val_accuracy: 0.7799
# Epoch 46/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5135 - accuracy: 0.8227 - val_loss: 0.7157 - val_accuracy: 0.7705
# Epoch 47/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5150 - accuracy: 0.8234 - val_loss: 0.7409 - val_accuracy: 0.7623
# Epoch 48/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5116 - accuracy: 0.8256 - val_loss: 0.6758 - val_accuracy: 0.7769
# Epoch 49/60
# 50000/50000 [==============================] - 63s 1ms/step - loss: 0.5096 - accuracy: 0.8261 - val_loss: 0.7108 - val_accuracy: 0.7753
# Epoch 50/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.4999 - accuracy: 0.8276 - val_loss: 0.6845 - val_accuracy: 0.7824
# Epoch 51/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.5009 - accuracy: 0.8288 - val_loss: 0.7074 - val_accuracy: 0.7722
# Epoch 52/60
# 50000/50000 [==============================] - 67s 1ms/step - loss: 0.4945 - accuracy: 0.8302 - val_loss: 0.7199 - val_accuracy: 0.7779
# Epoch 53/60
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.5004 - accuracy: 0.8297 - val_loss: 0.6961 - val_accuracy: 0.7767
# Epoch 54/60
# 50000/50000 [==============================] - 68s 1ms/step - loss: 0.4915 - accuracy: 0.8320 - val_loss: 0.7025 - val_accuracy: 0.7763
# Epoch 55/60
# 50000/50000 [==============================] - 62s 1ms/step - loss: 0.4771 - accuracy: 0.8394 - val_loss: 0.7028 - val_accuracy: 0.7754
# Epoch 56/60
# 50000/50000 [==============================] - 56s 1ms/step - loss: 0.4890 - accuracy: 0.8323 - val_loss: 0.7934 - val_accuracy: 0.7620
# Epoch 57/60
# 50000/50000 [==============================] - 57s 1ms/step - loss: 0.4847 - accuracy: 0.8353 - val_loss: 0.7165 - val_accuracy: 0.7713
# Epoch 58/60
# 50000/50000 [==============================] - 65s 1ms/step - loss: 0.4757 - accuracy: 0.8397 - val_loss: 0.7044 - val_accuracy: 0.7736
# Epoch 59/60
# 50000/50000 [==============================] - 69s 1ms/step - loss: 0.4775 - accuracy: 0.8377 - val_loss: 0.7288 - val_accuracy: 0.7757
# Epoch 60/60
# 50000/50000 [==============================] - 71s 1ms/step - loss: 0.4754 - accuracy: 0.8382 - val_loss: 0.7076 - val_accuracy: 0.7836

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
    # plot loss
    plt.subplot(211)
    plt.title('Cross Entropy Loss')
    plt.plot(history.history['loss'], color='blue', label='train')
    plt.plot(history.history['val_loss'], color='orange', label='test')
    # plot accuracy
    plt.subplot(212)
    plt.title('Classification Accuracy')
    plt.plot(history.history['accuracy'], color='blue', label='train')
    plt.plot(history.history['val_accuracy'], color='orange', label='test')
    # save plot to file
#     filename = sys.argv[0].split('/')[-1]
#     plt.savefig(filename + '_plot.png')
    plt.show()
#     plt.close()

# %%
_, acc = cnn_n.evaluate(x_test, y_test, verbose=0)
print('Accuracy is %.3f' % (acc * 100.0))
# Out:
# Accuracy is 78.360

# %%
summarize_diagnostics(cnn)

# %%
def base_model_2():

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))

# Train model

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
cnn_n_2 = base_model_2()
cnn_n_2.summary()

# Fit model

cnn = cnn_n_2.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test,y_test),shuffle=True)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_90 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_91 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d_65 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_92 (Conv2D)           (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_66 (MaxPooling (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_67 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 512)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_39 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                650
# =================================================================
# Total params: 361,578
# Trainable params: 361,578
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/60
# 50000/50000 [==============================] - 130s 3ms/step - loss: 1.7970 - accuracy: 0.3170 - val_loss: 1.3819 - val_accuracy: 0.4994
# Epoch 2/60
# 50000/50000 [==============================] - 136s 3ms/step - loss: 1.2845 - accuracy: 0.5342 - val_loss: 1.0647 - val_accuracy: 0.6225
# Epoch 3/60
# 50000/50000 [==============================] - 138s 3ms/step - loss: 1.0630 - accuracy: 0.6249 - val_loss: 0.8934 - val_accuracy: 0.6891
# Epoch 4/60
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.9329 - accuracy: 0.6752 - val_loss: 0.8792 - val_accuracy: 0.6977
# Epoch 5/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.8594 - accuracy: 0.7020 - val_loss: 0.7760 - val_accuracy: 0.7323
# Epoch 6/60
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.8005 - accuracy: 0.7214 - val_loss: 0.7677 - val_accuracy: 0.7346
# Epoch 7/60
# 50000/50000 [==============================] - 132s 3ms/step - loss: 0.7606 - accuracy: 0.7374 - val_loss: 0.7512 - val_accuracy: 0.7431
# Epoch 8/60
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.7295 - accuracy: 0.7485 - val_loss: 0.7258 - val_accuracy: 0.7540
# Epoch 9/60
# 50000/50000 [==============================] - 138s 3ms/step - loss: 0.7025 - accuracy: 0.7580 - val_loss: 0.6947 - val_accuracy: 0.7673
# Epoch 10/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.6788 - accuracy: 0.7663 - val_loss: 0.6783 - val_accuracy: 0.7718
# Epoch 11/60
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.6563 - accuracy: 0.7735 - val_loss: 0.6766 - val_accuracy: 0.7710
# Epoch 12/60
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.6369 - accuracy: 0.7809 - val_loss: 0.7036 - val_accuracy: 0.7706
# Epoch 13/60
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.6195 - accuracy: 0.7872 - val_loss: 0.6904 - val_accuracy: 0.7669
# Epoch 14/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.6024 - accuracy: 0.7928 - val_loss: 0.6478 - val_accuracy: 0.7862
# Epoch 15/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.5919 - accuracy: 0.7949 - val_loss: 0.6258 - val_accuracy: 0.7947
# Epoch 16/60
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.5755 - accuracy: 0.8014 - val_loss: 0.6893 - val_accuracy: 0.7694
# Epoch 17/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.5652 - accuracy: 0.8052 - val_loss: 0.6402 - val_accuracy: 0.7868
# Epoch 18/60
# 50000/50000 [==============================] - 136s 3ms/step - loss: 0.5513 - accuracy: 0.8101 - val_loss: 0.6196 - val_accuracy: 0.7946
# Epoch 19/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.5427 - accuracy: 0.8126 - val_loss: 0.6326 - val_accuracy: 0.7911
# Epoch 20/60
# 50000/50000 [==============================] - 123s 2ms/step - loss: 0.5292 - accuracy: 0.8180 - val_loss: 0.6397 - val_accuracy: 0.7869
# Epoch 21/60
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.5275 - accuracy: 0.8186 - val_loss: 0.6422 - val_accuracy: 0.7920
# Epoch 22/60
# 50000/50000 [==============================] - 133s 3ms/step - loss: 0.5186 - accuracy: 0.8220 - val_loss: 0.6293 - val_accuracy: 0.7977
# Epoch 23/60
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.5065 - accuracy: 0.8258 - val_loss: 0.6451 - val_accuracy: 0.7936
# Epoch 24/60
# 50000/50000 [==============================] - 135s 3ms/step - loss: 0.5017 - accuracy: 0.8270 - val_loss: 0.6550 - val_accuracy: 0.7915
# Epoch 25/60
# 50000/50000 [==============================] - 133s 3ms/step - loss: 0.4974 - accuracy: 0.8292 - val_loss: 0.6381 - val_accuracy: 0.7943
# Epoch 26/60
# 50000/50000 [==============================] - 130s 3ms/step - loss: 0.4900 - accuracy: 0.8314 - val_loss: 0.6304 - val_accuracy: 0.7985
# Epoch 27/60
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.4843 - accuracy: 0.8336 - val_loss: 0.6499 - val_accuracy: 0.7982
# Epoch 28/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4737 - accuracy: 0.8359 - val_loss: 0.6208 - val_accuracy: 0.7999
# Epoch 29/60
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.4685 - accuracy: 0.8381 - val_loss: 0.6431 - val_accuracy: 0.7934
# Epoch 30/60
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.4650 - accuracy: 0.8412 - val_loss: 0.6307 - val_accuracy: 0.8004
# Epoch 31/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4607 - accuracy: 0.8428 - val_loss: 0.6125 - val_accuracy: 0.8057
# Epoch 32/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4543 - accuracy: 0.8440 - val_loss: 0.6134 - val_accuracy: 0.8067
# Epoch 33/60
# 50000/50000 [==============================] - 131s 3ms/step - loss: 0.4519 - accuracy: 0.8478 - val_loss: 0.6304 - val_accuracy: 0.8014
# Epoch 34/60
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.4479 - accuracy: 0.8477 - val_loss: 0.6705 - val_accuracy: 0.7842
# Epoch 35/60
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.4465 - accuracy: 0.8485 - val_loss: 0.6121 - val_accuracy: 0.8049
# Epoch 36/60
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.4383 - accuracy: 0.8528 - val_loss: 0.6483 - val_accuracy: 0.8043
# Epoch 37/60
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.4417 - accuracy: 0.8501 - val_loss: 0.6236 - val_accuracy: 0.8033
# Epoch 38/60
# 50000/50000 [==============================] - 136s 3ms/step - loss: 0.4294 - accuracy: 0.8548 - val_loss: 0.6281 - val_accuracy: 0.8077
# Epoch 39/60
# 50000/50000 [==============================] - 128s 3ms/step - loss: 0.4268 - accuracy: 0.8537 - val_loss: 0.6049 - val_accuracy: 0.8156
# Epoch 40/60
# 50000/50000 [==============================] - 130s 3ms/step - loss: 0.4244 - accuracy: 0.8552 - val_loss: 0.6201 - val_accuracy: 0.8108
# Epoch 41/60
# 50000/50000 [==============================] - 130s 3ms/step - loss: 0.4182 - accuracy: 0.8567 - val_loss: 0.6416 - val_accuracy: 0.8067
# Epoch 42/60
# 50000/50000 [==============================] - 130s 3ms/step - loss: 0.4186 - accuracy: 0.8603 - val_loss: 0.6266 - val_accuracy: 0.8028
# Epoch 43/60
# 50000/50000 [==============================] - 139s 3ms/step - loss: 0.4062 - accuracy: 0.8605 - val_loss: 0.6366 - val_accuracy: 0.8068
# Epoch 44/60
# 50000/50000 [==============================] - 137s 3ms/step - loss: 0.4170 - accuracy: 0.8594 - val_loss: 0.6263 - val_accuracy: 0.8049
# Epoch 45/60
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.4032 - accuracy: 0.8638 - val_loss: 0.6463 - val_accuracy: 0.8059
# Epoch 46/60
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.4043 - accuracy: 0.8636 - val_loss: 0.6552 - val_accuracy: 0.8046
# Epoch 47/60
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.4011 - accuracy: 0.8651 - val_loss: 0.6370 - val_accuracy: 0.8047
# Epoch 48/60
# 50000/50000 [==============================] - 127s 3ms/step - loss: 0.3963 - accuracy: 0.8671 - val_loss: 0.6518 - val_accuracy: 0.8117
# Epoch 49/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.3909 - accuracy: 0.8694 - val_loss: 0.6537 - val_accuracy: 0.8043
# Epoch 50/60
# 50000/50000 [==============================] - 125s 3ms/step - loss: 0.3914 - accuracy: 0.8694 - val_loss: 0.6479 - val_accuracy: 0.8116
# Epoch 51/60
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.3842 - accuracy: 0.8723 - val_loss: 0.6481 - val_accuracy: 0.8087
# Epoch 52/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.3865 - accuracy: 0.8706 - val_loss: 0.6660 - val_accuracy: 0.8059
# Epoch 53/60
# 50000/50000 [==============================] - 129s 3ms/step - loss: 0.3908 - accuracy: 0.8690 - val_loss: 0.6366 - val_accuracy: 0.8102
# Epoch 54/60
# 50000/50000 [==============================] - 126s 3ms/step - loss: 0.3842 - accuracy: 0.8711 - val_loss: 0.6510 - val_accuracy: 0.8119
# Epoch 55/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.3789 - accuracy: 0.8744 - val_loss: 0.6619 - val_accuracy: 0.8080
# Epoch 56/60
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.3766 - accuracy: 0.8746 - val_loss: 0.7004 - val_accuracy: 0.8047
# Epoch 57/60
# 50000/50000 [==============================] - 124s 2ms/step - loss: 0.3810 - accuracy: 0.8734 - val_loss: 0.6862 - val_accuracy: 0.8152
# Epoch 58/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.3671 - accuracy: 0.8781 - val_loss: 0.6797 - val_accuracy: 0.8088
# Epoch 59/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.3726 - accuracy: 0.8765 - val_loss: 0.6576 - val_accuracy: 0.8095
# Epoch 60/60
# 50000/50000 [==============================] - 125s 2ms/step - loss: 0.3696 - accuracy: 0.8782 - val_loss: 0.6303 - val_accuracy: 0.8141

# %%
_, acc = cnn_n_2.evaluate(x_test, y_test, verbose=0)
print('Accuracy is %.3f' % (acc * 100.0))
# Out:
# Accuracy is 81.410

# %%
summarize_diagnostics(cnn)

# %%
def base_model_3():

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=x_train.shape[1:], activation='relu'))
    model.add(Conv2D(32, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))
    
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.4))
    
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(10, activation='softmax'))

# Train model

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model
cnn_n_3 = base_model_3()
cnn_n_3.summary()

# Fit model

cnn = cnn_n_3.fit(x_train, y_train, batch_size=batch_size, epochs=20,validation_data=(x_test,y_test),shuffle=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 128)         73856
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 361,578
# Trainable params: 361,578
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 134s 3ms/step - loss: 1.8038 - accuracy: 0.3067 - val_loss: 1.4383 - val_accuracy: 0.4671
# Epoch 2/20
# 50000/50000 [==============================] - 132s 3ms/step - loss: 1.4249 - accuracy: 0.4820 - val_loss: 1.2684 - val_accuracy: 0.5440
# Epoch 3/20
# 50000/50000 [==============================] - 128s 3ms/step - loss: 1.2552 - accuracy: 0.5532 - val_loss: 1.1262 - val_accuracy: 0.5916
# Epoch 4/20
# 50000/50000 [==============================] - 206s 4ms/step - loss: 1.1554 - accuracy: 0.5972 - val_loss: 0.9830 - val_accuracy: 0.6528
# Epoch 5/20
# 50000/50000 [==============================] - 207s 4ms/step - loss: 1.0785 - accuracy: 0.6179 - val_loss: 0.9689 - val_accuracy: 0.6607
# Epoch 6/20
# 50000/50000 [==============================] - 202s 4ms/step - loss: 1.0207 - accuracy: 0.6421 - val_loss: 0.9129 - val_accuracy: 0.6885
# Epoch 7/20
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.9719 - accuracy: 0.6627 - val_loss: 0.8878 - val_accuracy: 0.6939
# Epoch 8/20
# 50000/50000 [==============================] - 201s 4ms/step - loss: 0.9385 - accuracy: 0.6763 - val_loss: 0.8119 - val_accuracy: 0.7188
# Epoch 9/20
# 50000/50000 [==============================] - 204s 4ms/step - loss: 0.9112 - accuracy: 0.6863 - val_loss: 0.7781 - val_accuracy: 0.7321
# Epoch 10/20
# 50000/50000 [==============================] - 213s 4ms/step - loss: 0.8773 - accuracy: 0.6989 - val_loss: 0.8186 - val_accuracy: 0.7195
# Epoch 11/20
# 50000/50000 [==============================] - 202s 4ms/step - loss: 0.8616 - accuracy: 0.7049 - val_loss: 0.7880 - val_accuracy: 0.7299
# Epoch 12/20
# 50000/50000 [==============================] - 204s 4ms/step - loss: 0.8348 - accuracy: 0.7155 - val_loss: 0.7704 - val_accuracy: 0.7390
# Epoch 13/20
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.8194 - accuracy: 0.7202 - val_loss: 0.7394 - val_accuracy: 0.7488
# Epoch 14/20
# 50000/50000 [==============================] - 204s 4ms/step - loss: 0.8083 - accuracy: 0.7259 - val_loss: 0.7488 - val_accuracy: 0.7405
# Epoch 15/20
# 50000/50000 [==============================] - 207s 4ms/step - loss: 0.7886 - accuracy: 0.7337 - val_loss: 0.7213 - val_accuracy: 0.7539
# Epoch 16/20
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.7755 - accuracy: 0.7368 - val_loss: 0.7032 - val_accuracy: 0.7628
# Epoch 17/20
# 50000/50000 [==============================] - 204s 4ms/step - loss: 0.7616 - accuracy: 0.7407 - val_loss: 0.7233 - val_accuracy: 0.7539
# Epoch 18/20
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.7568 - accuracy: 0.7442 - val_loss: 0.7392 - val_accuracy: 0.7503
# Epoch 19/20
# 50000/50000 [==============================] - 212s 4ms/step - loss: 0.7525 - accuracy: 0.7469 - val_loss: 0.7072 - val_accuracy: 0.7566
# Epoch 20/20
# 50000/50000 [==============================] - 203s 4ms/step - loss: 0.7321 - accuracy: 0.7529 - val_loss: 0.7303 - val_accuracy: 0.7590

# %% [markdown]
# ### ~ Got poor performace when applied the increasing Dropout strategy
